# %% [markdown]
# # 01_data_raw: Loading Raw Wine Production Data
#
# ## Loading raw wine production data
#
# In this notebook, we will:
#
# 1. Load the raw wine production data per municipality (Excel file).
# 2. Inspect the first few rows to verify correctness.
# 3. Save the dataset as CSV for easier processing in later steps.

# %%
import pandas as pd

file_path = r"C:\Users\islec\climate-wine-project\data_raw\wine_production_raw.xlsx"

# Carregar aba 22 sem header
df = pd.read_excel(file_path, sheet_name=21, header=None)

# Definir colunas manualmente
df.columns = ['Distrito', 'Concelho', 'Vinho_Tinto', 'Vinho_Rosado', 'Vinho_Branco', 'Vinho_Total',
              'IndCasta_Tinto', 'IndCasta_Rosado', 'IndCasta_Branco', 'IndCasta_Total',
              'IGP_Tinto', 'IGP_Rosado', 'IGP_Branco', 'IGP_Total',
              'LicorosoDOP_Tinto', 'LicorosoDOP_Rosado', 'LicorosoDOP_Branco', 'LicorosoDOP_Total',
              'DOP_Tinto', 'DOP_Rosado', 'DOP_Branco', 'DOP_Total',
              'TotalGeral_Tinto', 'TotalGeral_Rosado', 'TotalGeral_Branco', 'TotalGeral_Total']

# Selecionar apenas produção de vinho
df_clean = df[['Distrito', 'Concelho', 'Vinho_Tinto', 'Vinho_Rosado', 'Vinho_Branco', 'Vinho_Total']]

# Remover linhas onde 'Concelho' está vazio ou 'Distrito' contém título/total
df_clean = df_clean[df_clean['Concelho'].notna()]
df_clean = df_clean[~df_clean['Distrito'].str.contains('Total|Distrito|Produção', na=False)]

# Preencher nomes de distrito
df_clean['Distrito'] = df_clean['Distrito'].ffill()

# Converter valores para numérico
for col in ['Vinho_Tinto', 'Vinho_Rosado', 'Vinho_Branco', 'Vinho_Total']:
    df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce').fillna(0)

# Resetar índice
df_clean.reset_index(drop=True, inplace=True)

# Salvar CSV final
df_clean.to_csv(r"C:\Users\islec\climate-wine-project\data_clean\wine_production_clean.csv", index=False)

print("CSV limpo final gerado com sucesso!")
print(df_clean.head(20))
# Out:
# CSV limpo final gerado com sucesso!
#    Distrito              Concelho  Vinho_Tinto  Vinho_Rosado  Vinho_Branco  \
# 0    Aveiro                Águeda       324.00        660.00        389.50
# 1    Aveiro    Albergaria-a-Velha        29.40          0.00          0.34
# 2    Aveiro                Anadia     15377.55       8440.12       5908.01
# 3    Aveiro                Arouca         4.00          0.00          0.00
# 4    Aveiro                Aveiro        80.00          0.00         23.00
# 5    Aveiro      Castelo de Paiva        40.00          0.00        179.00
# 6    Aveiro             Estarreja        16.00          0.00          6.00
# 7    Aveiro                Ílhavo         7.50          4.00          0.00
# 8    Aveiro              Mealhada      3286.90          5.00        473.35
# 9    Aveiro   Oliveira de Azeméis         2.06          0.00          0.00
# 10   Aveiro    Oliveira do Bairro      4895.35         35.50        900.85
# 11   Aveiro  Santa Maria da Feira         0.00          0.00          0.00
# 12   Aveiro        Sever do Vouga        60.00          0.00          0.00
# 13   Aveiro                 Vagos       109.30          0.00          0.00
# 14   Aveiro        Vale de Cambra        30.00        131.77         95.00
# 15     Beja             Aljustrel       570.00          0.00        540.00
# 16     Beja                Alvito         0.00          0.00          0.00
# 17     Beja                  Beja        45.00          0.00         21.00
# 18     Beja          Castro Verde         0.00          0.00          0.00
# 19     Beja                  Cuba         0.00          0.00          0.00
#
#     Vinho_Total
# 0       1373.50
# 1         29.74
# 2      29725.68
# 3          4.00
# 4        103.00
# 5        219.00
# 6         22.00
# 7         11.50
# 8       3765.25
# 9          2.06
# 10      5831.70
# 11         0.00
# 12        60.00
# 13       109.30
# 14       256.77
# 15      1110.00
# 16         0.00
# 17        66.00
# 18         0.00
# 19         0.00

# %%
# Agrupar concelhos por distrito
resumo_concelhos = df_clean.groupby('Distrito')['Concelho'].apply(list)

# Mostrar resumo
for distrito, concelhos in resumo_concelhos.items():
    print(f"{distrito} ({len(concelhos)} concelhos): {concelhos}\n")
# Out:
# Aveiro (15 concelhos): ['Águeda', 'Albergaria-a-Velha', 'Anadia', 'Arouca', 'Aveiro', 'Castelo de Paiva', 'Estarreja', 'Ílhavo', 'Mealhada', 'Oliveira de Azeméis', 'Oliveira do Bairro', 'Santa Maria da Feira', 'Sever do Vouga', 'Vagos', 'Vale de Cambra']
#
# Aveiro - Total (1 concelhos): [nan]
#
# Açores (13 concelhos): ['Angra do Heroísmo', 'Praia da Vitória', 'Santa Cruz da Graciosa', 'Vila do Porto', 'Horta', 'Lajes do Pico', 'Madalena', 'São Roque do Pico', 'Calheta (São Jorge)', 'Velas', 'Ponta Delgada', 'Povoação', 'Vila Franca do Campo']
#
# Beja (12 concelhos): ['Aljustrel', 'Alvito', 'Beja', 'Castro Verde', 'Cuba', 'Ferreira do Alentejo', 'Mértola', 'Moura', 'Odemira', 'Ourique', 'Serpa', 'Vidigueira']
#
# Beja - Total (1 concelhos): [nan]
#
# Braga (14 concelhos): ['Amares', 'Barcelos', 'Braga', 'Cabeceiras de Basto', 'Celorico de Basto', 'Esposende', 'Fafe', 'Guimarães', 'Póvoa de Lanhoso', 'Terras de Bouro', 'Vieira do Minho', 'Vila Nova de Famalicão', 'Vila Verde', 'Vizela']
#
# Braga - Total (1 concelhos): [nan]
#
# Bragança (12 concelhos): ['Alfandega da Fé', 'Bragança', 'Carrazeda de Ansiães', 'Freixo Espada à Cinta', 'Macedo de Cavaleiros', 'Miranda do Douro', 'Mirandela', 'Mogadouro', 'Torre de Moncorvo', 'Vila Flor', 'Vimioso', 'Vinhais']
#
# Bragança - Total (1 concelhos): [nan]
#
# Castelo Branco (9 concelhos): ['Belmonte', 'Castelo Branco', 'Covilhã', 'Fundão', 'Oleiros', 'Penamacor', 'Proença-a-Nova', 'Sertã', 'Vila Velha de Rodão']
#
# Castelo Branco - Total (1 concelhos): [nan]
#
# Coimbra (13 concelhos): ['Arganil', 'Cantanhede', 'Coimbra', 'Condeixa-a-Nova', 'Figueira da Foz', 'Lousã', 'Miranda do Corvo', 'Montemor-o-Velho', 'Oliveira do Hospital', 'Penacova', 'Penela', 'Soure', 'Tábua']
#
# Coimbra - Total (1 concelhos): [nan]
#
# Distrito (2 concelhos): ['Concelho', nan]
#
# Faro (14 concelhos): ['Albufeira', 'Aljezur', 'Castro Marim', 'Faro', 'Lagoa (Algarve)', 'Lagos', 'Loulé', 'Monchique', 'Portimão', 'São Brás de Alportel', 'Silves', 'Tavira', 'Vila do Bispo', 'Vila Real Santo António']
#
# Faro - Total (1 concelhos): [nan]
#
# Guarda (12 concelhos): ['Aguiar da Beira', 'Almeida', 'Celorico da Beira', 'Figueira Castelo Rodrigo', 'Fornos de Algodres', 'Gouveia', 'Guarda', 'Meda', 'Pinhel', 'Seia', 'Trancoso', 'Vila Nova de Foz Côa']
#
# Guarda - Total (1 concelhos): [nan]
#
# Ihas da Terceira e Graciosa - Total (1 concelhos): [nan]
#
# Ilha Santa Maria - Total (1 concelhos): ['Vila do Porto']
#
# Ilha de São Miguel - Total (1 concelhos): [nan]
#
# Ilhas da Madeira e Porto Santo - Total (1 concelhos): [nan]
#
# Ilhas do Faial, Pico e São Jorge - total (1 concelhos): [nan]
#
# Leiria (13 concelhos): ['Alcobaça', 'Alvaiázere', 'Ansião', 'Batalha', 'Bombarral', 'Caldas da Rainha', 'Figueiró dos Vinhos', 'Leiria', 'Óbidos', 'Pedrógão Grande', 'Peniche', 'Pombal', 'Porto de Mós']
#
# Leiria - Total (1 concelhos): [nan]
#
# Lisboa (14 concelhos): ['Alenquer', 'Arruda dos Vinhos', 'Azambuja', 'Cadaval', 'Lisboa', 'Loures', 'Lourinhã', 'Mafra', 'Odivelas', 'Oeiras', 'Sintra', 'Sobral de Monte Agraço', 'Torres Vedras', 'Vila Franca de Xira']
#
# Lisboa - Total (1 concelhos): [nan]
#
# Madeira (11 concelhos): ['Calheta', 'Câmara de Lobos', 'Funchal', 'Machico', 'Ponta do Sol', 'Porto Moniz', 'Porto Santo', 'Ribeira Brava', 'Santa Cruz', 'Santana', 'São Vicente']
#
# Portalegre (15 concelhos): ['Alter do Chão', 'Arronches', 'Avis', 'Campo Maior', 'Castelo de Vide', 'Crato', 'Elvas', 'Fronteira', 'Gavião', 'Marvão', 'Monforte', 'Nisa', 'Ponte de Sor', 'Portalegre', 'Sousel']
#
# Portalegre - Total (1 concelhos): [nan]
#
# Porto (18 concelhos): ['Amarante', 'Baião', 'Felgueiras', 'Gondomar', 'Lousada', 'Maia', 'Marco de Canaveses', 'Matosinhos', 'Paços de Ferreira', 'Paredes', 'Penafiel', 'Porto', 'Póvoa de Varzim', 'Santo Tirso', 'Trofa', 'Valongo', 'Vila do Conde', 'Vila Nova de Gaia']
#
# Porto - Total (1 concelhos): [nan]
#
# Santarém (17 concelhos): ['Abrantes', 'Almeirim', 'Alpiarça', 'Benavente', 'Cartaxo', 'Chamusca', 'Coruche', 'Ferreira do Zêzere', 'Golegã', 'Mação', 'Ourém', 'Rio Maior', 'Salvaterra de Magos', 'Santarém', 'Sardoal', 'Tomar', 'Torres Novas']
#
# Santarém - Total (1 concelhos): [nan]
#
# Setúbal (10 concelhos): ['Alcácer do Sal', 'Alcochete', 'Almada', 'Barreiro', 'Grândola', 'Montijo', 'Palmela', 'Santiago do Cacém', 'Sesimbra', 'Setúbal']
#
# Setúbal - Total (1 concelhos): [nan]
#
# Total Geral (1 concelhos): [nan]
#
# Viana do Castelo (9 concelhos): ['Arcos de Valdevez', 'Caminha', 'Melgaço', 'Monção', 'Ponte da Barca', 'Ponte de Lima', 'Valença', 'Viana do Castelo', 'Vila Nova de Cerveira']
#
# Viana do Castelo - Total (1 concelhos): [nan]
#
# Vila Real (14 concelhos): ['Alijó', 'Boticas', 'Chaves', 'Mesão Frio', 'Mondim de Basto', 'Montalegre', 'Murça', 'Peso da Régua', 'Ribeira de Pena', 'Sabrosa', 'Santa Marta Penaguião', 'Valpaços', 'Vila Pouca de Aguiar', 'Vila Real']
#
# Vila Real - Total (1 concelhos): [nan]
#
# Viseu (22 concelhos): ['Armamar', 'Carregal do Sal', 'Cinfães', 'Lamego', 'Mangualde', 'Moimenta da Beira', 'Mortágua', 'Nelas', 'Oliveira de Frades', 'Penalva do Castelo', 'Penedono', 'Resende', 'Santa Comba Dão', 'São João da Pesqueira', 'São Pedro do Sul', 'Sátão', 'Sernancelhe', 'Tabuaço', 'Tarouca', 'Tondela', 'Viseu', 'Vouzela']
#
# Viseu - Total (1 concelhos): [nan]
#
# Évora (13 concelhos): ['Arraiolos', 'Borba', 'Estremoz', 'Évora', 'Montemor-o-Novo', 'Mora', 'Mourão', 'Portel', 'Redondo', 'Reguengos Monsaraz', 'Vendas Novas', 'Viana do Alentejo', 'Vila Viçosa']
#
# Évora - Total (1 concelhos): [nan]
